# %% [markdown]
# ## 1. 管理工具安装
# ### 1.1 langchain 安装

# %%
# !pip install langchain

# conda 
# conda install -c conda-forge langchain
# Out:
# Requirement already satisfied: langchain in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.2)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.3.0)

# %% [markdown]
# ### 1.2 其他库安装

# %%
# 直接转换为 REST API
# !pip install "langserve[all]"

# 观测平台
# !pip install -U langsmith

# LangGraph
# !pip install -U langgraph

# DeepSeek
# !pip install langchain-deepseek

# 外部资源集成
# !pip install langchain_community

# dotenv管理密钥，加载环境变量等
# !pip install python-dotenv
# Out:
# Requirement already satisfied: langserve[all] in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (0.3.3)
# Requirement already satisfied: fastapi<1,>=0.90.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (0.128.0)
# Requirement already satisfied: httpx<1.0,>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (0.28.1)
# Requirement already satisfied: langchain-core<2,>=0.3 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (1.2.7)
# Requirement already satisfied: orjson<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (3.11.4)
# Requirement already satisfied: pydantic<3.0,>=2.7 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (2.12.5)
# Requirement already satisfied: sse-starlette<2.0.0,>=1.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langserve[all]) (1.8.2)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from fastapi<1,>=0.90.1->langserve[all]) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from fastapi<1,>=0.90.1->langserve[all]) (0.0.4)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1.0,>=0.23.0->langserve[all]) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.23.0->langserve[all]) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2,>=0.3->langserve[all]) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=0.3->langserve[all]) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0,>=2.7->langserve[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0,>=2.7->langserve[all]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0,>=2.7->langserve[all]) (0.4.2)
# Requirement already satisfied: uvicorn in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from sse-starlette<2.0.0,>=1.3.0->langserve[all]) (0.38.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3->langserve[all]) (2.3.0)
# Requirement already satisfied: click>=7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all]) (8.3.1)
# Requirement already satisfied: langsmith in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (0.6.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (3.11.4)
# Requirement already satisfied: packaging>=23.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (24.2)
# Requirement already satisfied: pydantic<3,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (2.12.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (2.32.5)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (0.12.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3,>=2->langsmith) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3,>=2->langsmith) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3,>=2->langsmith) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3,>=2->langsmith) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith) (2.3.0)
# Requirement already satisfied: langgraph in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (1.0.6)
# Requirement already satisfied: langchain-core>=0.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (0.3.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.4)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core>=0.1->langgraph) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: langchain-deepseek in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-deepseek) (1.2.7)
# Requirement already satisfied: langchain-openai<2.0.0,>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-deepseek) (1.1.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.25.0)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (0.12.0)
# Requirement already satisfied: sniffio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai<2.0.0,>=1.0.0->langchain-deepseek) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-deepseek) (2.3.0)
# Requirement already satisfied: langchain_community in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (1.2.7)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (0.6.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: certifi in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: python-dotenv in /Users/anthony/miniforge3/envs/new_ai_env/lib/python3.11/site-packages (1.2.1)

# %% [markdown]
# ### 1.3 常见的处理链包含三个要素
#
# 1. 语言模型：核心推理引擎
# 2. 提示词模板：提供指令
# 3. 输出解释器：转换为易于使用的格式，便于下游处理

# %% [markdown]
# #### 1.3.1 语言模型
#
# langchain语言模型主要分为两种：
#
# 1. LLM 通用模型：接收字符串作为输入，输出字符串作为输出。
# 2. ChatModel 对话模型：接收消息列表，输出“消息”，用于一问一答。
#
# 消息：由 BaseMessage 类定义，包含文本、时间戳、用户标识符等属性。主要的有
#
# 1. 消息的内容：文本，通常是字符串
# 2. 角色：消息的发送方
#
# 角色： LangChain 用于区分不同角色的对象
#
# 1. HumanMessage：人类（用户）输入的BaseMessage。
# 2. AIMessage：AI助手（大模型）输出的BaseMessage。
# 3. SystemMessage：系统预设的BaseMessage。
# 4. FunctionMessage：自定义函数输出的BaseMessage。
# 5. ToolMessage：调用第三方工具输出的BaseMessage。
# 6. ChatMessage：自定义角色。
#
# 方法： LCEL 默认实现同步调用方法，最常见的是 invoke 方法，接受一个 BaseMessage 对象作为参数，并返回一个 BaseMessage 对象作为结果。
#
# 比如：
# LLMs.invoke：输入输出都是字符串
# ChatModels.invoke：输入输出都是BaseMessage对象

# %%
import os
from dotenv import load_dotenv, find_dotenv

# 加载 .env 文件
_ = load_dotenv(find_dotenv())

# 验证 Key 是否存在 (可选)
# print(os.environ.get("DASHSCOPE_API_KEY"))

# %%
import os
from dotenv import load_dotenv, find_dotenv

# 自动搜索并加载 .env 文件（会逐级向上查找）
env_path = find_dotenv()
loaded = load_dotenv(env_path)

print(f"Loading .env from: {env_path}")
print(f"Loaded successfully: {loaded}")

# 检查 Key 是否真的加载进来了 (只打印前几位，确保安全)
api_key = os.getenv("DASHSCOPE_API_KEY")
if api_key:
    print(f"API Key loaded: {api_key[:6]}******")
else:
    print("❌ API Key NOT found! Please check your .env file.")
# Out:
# Loading .env from: /Users/anthony/Desktop/llm/ai-engineer-training/week04/.env
# Loaded successfully: True
# API Key loaded: sk-080******

# %%
from langchain_deepseek import ChatDeepSeek

deepseek = ChatDeepSeek(model="deepseek-chat")

print(deepseek.invoke("你好"))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 from langchain_deepseek import ChatDeepSeek
#       3 deepseek = ChatDeepSeek(model="deepseek-chat")
# ----> 5 print(deepseek.invoke("你好"))
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)    281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: List[PromptValue],
#    (...)    783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:855, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     853 else:
#     854     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 855         result = self._generate(
#     856             messages, stop=stop, run_manager=run_manager, **kwargs
#     857         )
#     858     else:
#     859         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_deepseek/chat_models.py:356, in ChatDeepSeek._generate(self, messages, stop, run_manager, **kwargs)
#     348 def _generate(
#     349     self,
#     350     messages: list[BaseMessage],
#    (...)    353     **kwargs: Any,
#     354 ) -> ChatResult:
#     355     try:
# --> 356         return super()._generate(
#     357             messages,
#     358             stop=stop,
#     359             run_manager=run_manager,
#     360             **kwargs,
#     361         )
#     362     except JSONDecodeError as e:
#     363         msg = (
#     364             "DeepSeek API returned an invalid response. "
#     365             "Please check the API status and try again."
#     366         )
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:688, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     686     generation_info = {"headers": dict(raw_response.headers)}
#     687 else:
# --> 688     response = self.client.create(**payload)
#     689 return self._create_chat_result(response, generation_info)
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/new_ai_env/lib/python3.11/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Authentication Fails, Your api key: ****9dd7 is invalid', 'type': 'authentication_error', 'param': None, 'code': 'invalid_request_error'}}

# %% [markdown]
# #### 1.3.2 提示词模板
#
# 提示词模板是用于生成提示词的模板。例如，`{name}，你好！我是你的朋友小爱同学。`就是一个提示词模板。
#
# 提示词模板中可以使用变量，变量名由字母、数字和下划线组成，且必须以字母开头。例如，`{name}，你好！我是你的朋友小爱同学。`中的`{name}`就是一个变量。

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "Hello, I am a {model_name}. How can I help you today?"
)
prompt.format(model_name="chatbot")
# Out:
# 'Hello, I am a chatbot. How can I help you today?'

# %%
# 使用 ChatPromptTemplate 创建对话模板
from langchain_core.prompts import ChatPromptTemplate

# 创建包含 system 和 human 消息的聊天模板
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant named {assistant_name}."),
    ("human", "Hello, my name is {user_name}. {question}")
])

# 格式化消息
messages = chat_prompt.format_messages(
    assistant_name="Claude",
    user_name="Alice", 
    question="What's the weather like today?"
)

for message in messages:
    print(f"{message.type}: {message.content}")
# Out:
# system: You are a helpful AI assistant named Claude.
# human: Hello, my name is Alice. What's the weather like today?

# %%
from langchain_core.prompts import PromptTemplate

# 多变量模板
complex_prompt = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="""
    请为{audience}写一篇关于{topic}的文章。
    写作风格应该是{tone}的。
    
    文章要求：
    - 内容准确且有用
    - 结构清晰
    - 适合目标受众
    """
)

formatted_prompt = complex_prompt.format(
    topic="人工智能",
    audience="初学者",
    tone="通俗易懂"
)
print(formatted_prompt)
# Out:
#     请为初学者写一篇关于人工智能的文章。
#     写作风格应该是通俗易懂的。
#
#     文章要求：
#     - 内容准确且有用
#     - 结构清晰
#     - 适合目标受众

# %%
from langchain_core.prompts import PromptTemplate

# f-string 风格、jinja2语法 ...
f_string_prompt = PromptTemplate.from_template(
    "分析以下{data_type}数据：\n{data}\n\n请提供{analysis_type}分析。"
)

result = f_string_prompt.format(
    data_type="销售",
    data="Q1销售额: 100万, Q2销售额: 120万",
    analysis_type="趋势"
)
print(result)
# Out:
# 分析以下销售数据：
# Q1销售额: 100万, Q2销售额: 120万
#
# 请提供趋势分析。

# %%
from langchain_core.prompts import PromptTemplate

# 带条件逻辑的模板
conditional_prompt = PromptTemplate(
    input_variables=["user_type", "question"],
    template="""
    {%- if user_type == "expert" -%}
    作为专家，请详细回答：{question}
    {%- else -%}
    请用简单易懂的方式回答：{question}
    {%- endif -%}
    """
)

# %% [markdown]
# #### 1.3.3 输出解析器
#
# 输出解析器是 LangChain 中的重要组件，用于将大语言模型(LLM)的原始文本输出转换为结构化数据格式，便于程序进一步处理和使用。
#
# 主要功能
# - 格式化输出: 将 LLM 的自然语言输出解析为 JSON、XML、列表等结构化格式
# - 类型转换: 将文本数据转换为 Python 对象（字典、列表、自定义类等）
# - 数据验证: 确保输出符合预期的格式和约束条件
# - 错误处理: 处理解析失败的情况，提供重试机制
#
# 常见的输出解析器类型

# %%
# JSON 输出解析器
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

class PersonInfo(BaseModel):
    name: str = Field(description="人物姓名")
    age: int = Field(description="年龄")
    occupation: str = Field(description="职业")

parser = PydanticOutputParser(pydantic_object=PersonInfo)

# 列表输出解析器

from langchain_core.output_parsers import CommaSeparatedListOutputParser

parser = CommaSeparatedListOutputParser()
# 将 "苹果,香蕉,橙子" 解析为 ["苹果", "香蕉", "橙子"]

# 结构化输出解析器
from langchain_core.output_parsers import StructuredOutputParser, ResponseSchema

response_schemas = [
    ResponseSchema(name="answer", description="问题的答案"),
    ResponseSchema(name="source", description="答案来源")
]
parser = StructuredOutputParser.from_response_schemas(response_schemas)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 # JSON 输出解析器
# ----> 2 from langchain.output_parsers import PydanticOutputParser
#       3 from pydantic import BaseModel, Field
#       5 class PersonInfo(BaseModel):
#
# ModuleNotFoundError: No module named 'langchain.output_parsers'

# %%
# 手动使用解析器
parser = CommaSeparatedListOutputParser()

# 模拟 LLM 的原始输出
raw_output = "Python, Java, JavaScript, C++, Go"

# 解析输出
parsed_result = parser.parse(raw_output)
print("手动解析结果:", parsed_result)
# 输出: ['Python', 'Java', 'JavaScript', 'C++', 'Go']
# Out:
# 手动解析结果: ['Python', 'Java', 'JavaScript', 'C++', 'Go']

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_community.llms import Tongyi

# 初始化
parser = CommaSeparatedListOutputParser()
llm = Tongyi(temperature=0)

# 直接构建提示并调用
def simple_list_generation(category):
    # 手动构建提示
    prompt = f"""请列出5个{category}的例子。
{parser.get_format_instructions()}"""
    
    # 直接调用LLM
    response = llm.invoke(prompt)
    
    # 解析结果
    return parser.parse(response)


# 使用
fruits = simple_list_generation("水果")
print("水果列表:", fruits)

languages = simple_list_generation("编程语言")
print("编程语言列表:", languages)
# Out:
# 水果列表: ['apple', 'banana', 'orange', 'grape', 'strawberry']
# 编程语言列表: ['Python', 'Java', 'C++', 'JavaScript', 'Ruby']

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms.tongyi import Tongyi

# 1. 创建输出解析器
parser = CommaSeparatedListOutputParser()

# 2. 获取格式化指令
format_instructions = parser.get_format_instructions()
print("格式化指令:", format_instructions)

# 3. 创建包含格式指令的提示模板
prompt = PromptTemplate(
    template="请列出5个{category}的例子。\n{format_instructions}",
    input_variables=["category"],
    partial_variables={"format_instructions": format_instructions}
)

# 4. 初始化 LLM
llm = Tongyi(temperature=0)

# 5. 创建完整的链
chain = prompt | llm | parser

# 6. 使用示例
try:
    # 调用链并获取解析后的结果
    result = chain.invoke({"category": "水果"})
    print("解析后的结果:", result)
    print("结果类型:", type(result))
    # 输出示例: ['苹果', '香蕉', '橙子', '葡萄', '草莓']
    
    # 遍历结果
    for i, fruit in enumerate(result, 1):
        print(f"{i}. {fruit}")
        
except Exception as e:
    print(f"解析错误: {e}")

# 7. 更复杂的示例 - 多个类别
categories = ["编程语言", "运动项目", "乐器"]

for category in categories:
    print(f"\n=== {category} ===")
    try:
        result = chain.invoke({"category": category})
        for item in result:
            print(f"• {item}")
    except Exception as e:
        print(f"处理 {category} 时出错: {e}")
# Out:
# 格式化指令: Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
# 解析后的结果: ['苹果', '香蕉', '橙子', '葡萄', '草莓']
# 结果类型: <class 'list'>
# 1. 苹果
# 2. 香蕉
# 3. 橙子
# 4. 葡萄
# 5. 草莓
#
# === 编程语言 ===
# • Python
# • Java
# • C++
# • JavaScript
# • Ruby
#
# === 运动项目 ===
# • 篮球
# • 足球
# • 网球
# • 游泳
# • 田径
#
# === 乐器 ===
# • 钢琴
# • 吉他
# • 小提琴
# • 鼓
# • 长笛

# %%
# 购物清单
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import Tongyi

# 1. 初始化组件
parser = CommaSeparatedListOutputParser()
llm = Tongyi(temperature=0)

# 2. 创建提示模板
shopping_prompt = PromptTemplate(
    template="根据{meal_type}，生成一个包含5个食材的购物清单。\n{format_instructions}",
    input_variables=["meal_type"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# 3. 创建链
shopping_chain = shopping_prompt | llm | parser

# 4. 生成不同餐型的购物清单
meals = ["早餐", "午餐", "晚餐"]
shopping_lists = {}

for meal in meals:
    shopping_lists[meal] = shopping_chain.invoke({"meal_type": meal})
    print(f"{meal}购物清单: {shopping_lists[meal]}")

# 5. 格式化输出
print("\n=== 详细购物清单 ===")
for meal, items in shopping_lists.items():
    print(f"\n🍽️ {meal}:")
    for i, item in enumerate(items, 1):
        print(f"  {i}. {item}")
# Out:
# 早餐购物清单: ['牛奶', '鸡蛋', '面包', '黄油', '燕麦片']
# 午餐购物清单: ['面包', '火腿', '生菜', '番茄', '奶酪']
# 晚餐购物清单: ['鸡胸肉', '西兰花', '红椒', '大蒜', '橄榄油']
#
# === 详细购物清单 ===
#
# 🍽️ 早餐:
#   1. 牛奶
#   2. 鸡蛋
#   3. 面包
#   4. 黄油
#   5. 燕麦片
#
# 🍽️ 午餐:
#   1. 面包
#   2. 火腿
#   3. 生菜
#   4. 番茄
#   5. 奶酪
#
# 🍽️ 晚餐:
#   1. 鸡胸肉
#   2. 西兰花
#   3. 红椒
#   4. 大蒜
#   5. 橄榄油

# %%
# 多场景
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import Tongyi

# 通用列表生成链
parser = CommaSeparatedListOutputParser()
list_chain = (
    PromptTemplate(
        template="请列出5个{category}的{item_type}。\n{format_instructions}",
        input_variables=["category", "item_type"],
        partial_variables={"format_instructions": parser.get_format_instructions()}
    )
    | Tongyi(temperature=0)
    | parser
)

# 多场景使用
scenarios = [
    {"category": "早餐", "item_type": "食材"},
    {"category": "办公室", "item_type": "用品"},
    {"category": "旅行", "item_type": "必需品"},
    {"category": "健身", "item_type": "器材"},
    {"category": "学习", "item_type": "工具"}
]

for scenario in scenarios:
    result = list_chain.invoke(scenario)
    print(f"{scenario['category']}{scenario['item_type']}: {result}")
# Out:
# 早餐食材: ['鸡蛋', '牛奶', '面包', '燕麦', '香蕉']
# 办公室用品: ['Pen', 'Notebook', 'Stapler', 'Printer', 'Coffee Maker']
# 旅行必需品: ['护照', '钱包', '手机充电器', '水杯', '防晒霜']
# 健身器材: ['哑铃', '杠铃', '引体向上杆', '健身球', '跳绳']
# 学习工具: ['Anki', 'Quizlet', 'Notion', 'Duolingo', 'Khan Academy']

# %% [markdown]
# #### 1.3.4 使用 LCEL 的好处
#
# 1. 简洁语法: 使用管道操作符 | 创建链，代码直观易读
# 2. 自动类型推断: 组件间数据类型自动转换，减少手动处理
# 3. 并行处理: 内置并行执行能力，提高处理效率
# 4. 流式处理: 原生支持流式输出，适合实时应用
# 5. 智能缓存: 自动缓存中间结果，避免重复计算
# 6. 内置调试: 更好的调试和监控能力
# 7. 插件化: 支持自定义组件和扩展
# 8. 标准接口: 统一的 Runnable 接口
# 9. 版本管理: 支持链的版本控制和管理
